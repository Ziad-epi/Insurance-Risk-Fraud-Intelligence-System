# %% [markdown]
# # Fraud Detection
#
# Train a fraud detection model with SMOTE and Random Forest.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))

import pandas as pd
from src.models.fraud_model import train_fraud_model

df = pd.DataFrame({
    'feature_1': [1, 2, 3, 4],
    'feature_2': [0.1, 0.2, 0.3, 0.4],
    'fraud_label': [0, 0, 1, 0]
})

X = df.drop(columns=['fraud_label'])
y = df['fraud_label']

model = train_fraud_model(X, y, n_estimators=50, max_depth=5)
model
