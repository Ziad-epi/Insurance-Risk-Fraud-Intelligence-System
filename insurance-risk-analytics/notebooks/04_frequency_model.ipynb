# %% [markdown]
# # Frequency Model
#
# Train a Poisson GLM to model claim frequency.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))

from src.models.frequency_model import train_frequency_model
from src.data.data_loader import load_policy_data
from src.data.data_preprocessing import clean_data, encode_features

df = clean_data(load_policy_data())
df = encode_features(df)

# Placeholder target for demonstration
df['number_of_claims'] = 0

X = df.drop(columns=['number_of_claims'])
y = df['number_of_claims']

model = train_frequency_model(X, y)
model.summary()
