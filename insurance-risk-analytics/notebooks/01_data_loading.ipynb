# %% [markdown]
# # Data Loading
#
# Load policy and claim datasets and inspect their structure.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))

from src.data.data_loader import load_policy_data, load_claim_data

policy_df = load_policy_data()
claim_df = load_claim_data()

policy_df.head(), claim_df.head()
