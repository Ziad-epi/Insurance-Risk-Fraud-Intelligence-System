# %% [markdown]
# # Pure Premium
#
# Compute pure premium from frequency and severity predictions.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))

import pandas as pd
from src.models.pricing_model import compute_pure_premium

df = pd.DataFrame({
    'expected_claim_frequency': [0.2, 0.5],
    'expected_claim_severity': [1500, 2300],
    'premium': [1200, 1800]
})

compute_pure_premium(df)
