# %% [markdown]
# # Feature Engineering
#
# Create engineered features such as claim-to-premium ratio and flags.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))

from src.data.data_loader import load_policy_data
from src.features.feature_engineering import create_features
from src.data.data_preprocessing import clean_data

policy_df = load_policy_data()
df = clean_data(policy_df)
df = create_features(df)
df.head()
