# %% [markdown]
# # Severity Model
#
# Train a Gamma GLM to model claim severity.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))

from src.models.severity_model import train_severity_model
from src.data.data_loader import load_claim_data
from src.data.data_preprocessing import clean_data, encode_features

df = clean_data(load_claim_data())
df = encode_features(df)

# Placeholder target for demonstration
df['claim_amount'] = df.get('claim_amount', 1)

X = df.drop(columns=['claim_amount'])
y = df['claim_amount']

model = train_severity_model(X, y)
model.summary()
